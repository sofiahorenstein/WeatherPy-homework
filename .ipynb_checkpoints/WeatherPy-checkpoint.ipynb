# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
print("Data Insights")

1.
# Out:
# Data Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#target url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lats = []
lngs = []
max_temps = []
wind_speeds = []

record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:
    #response = requests.get(query_url + city).json()
    #lat.append(response['coord']['lat'])
    #temp.append(response['main']['temp'])
    #target url
    url = "http://api.openweathermap.org/data/2.5/weather?"
    units = "imperial"

# Build partial query URL
    query_url = f"{url}APPID={api_key}&units={units}&q="
    
    try: 
        response = requests.get(query_url + city).json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temps.append(response["main"]["temp_max"])
        lats.append(response["coord"]["lat"])
        lngs.append(response["coord"]["lon"])
        wind_speeds.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        #print(f"{query_url} + {city}")
        
        # Increase counter by one 
        record= record + 1
        
        
    # If no record found "skip" to next call
    except:
        #response = requests.get(query_url + city).json() 
        print("city not found")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Busselton
# Processing Record 2 | Khatanga
# Processing Record 3 | Cockburn Town
# Processing Record 4 | La Sarre
# Processing Record 5 | Rikitea
# city not found
# Processing Record 6 | Upernavik
# Processing Record 7 | Yellowknife
# Processing Record 8 | Kapaa
# Processing Record 9 | New Norfolk
# Processing Record 10 | Mataura
# Processing Record 11 | Port Alfred
# city not found
# Processing Record 12 | Margate
# Processing Record 13 | Ribeira Grande
# Processing Record 14 | Saskylakh
# Processing Record 15 | Kavieng
# Processing Record 16 | Avarua
# Processing Record 17 | Leningradskiy
# Processing Record 18 | Punta Arenas
# Processing Record 19 | Pokhara
# Processing Record 20 | Albany
# Processing Record 21 | Hofn
# Processing Record 22 | Cherskiy
# Processing Record 23 | Inongo
# Processing Record 24 | Bredasdorp
# Processing Record 25 | Yar-Sale
# city not found
# Processing Record 26 | Mayumba
# Processing Record 27 | Thompson
# Processing Record 28 | Barrow
# city not found
# Processing Record 29 | Bubaque
# Processing Record 30 | Haines Junction
# Processing Record 31 | Kodiak
# Processing Record 32 | Katsuura
# Processing Record 33 | Sept-Iles
# Processing Record 34 | Korfovskiy
# Processing Record 35 | Fortuna
# Processing Record 36 | Eyl
# Processing Record 37 | Nouadhibou
# Processing Record 38 | Jamestown
# Processing Record 39 | Gladstone
# Processing Record 40 | Fort Nelson
# Processing Record 41 | Jumla
# Processing Record 42 | Mar del Plata
# Processing Record 43 | Rio Grande
# Processing Record 44 | Ushuaia
# city not found
# Processing Record 45 | Ponta do Sol
# Processing Record 46 | Qaanaaq
# Processing Record 47 | Cumberland
# Processing Record 48 | Lahij
# Processing Record 49 | Zyryanka
# Processing Record 50 | Camacha
# Processing Record 51 | Sao Filipe
# Processing Record 52 | Airai
# Processing Record 53 | Jawhar
# Processing Record 54 | Clyde River
# Processing Record 55 | Cornwall
# Processing Record 56 | Miquelon
# city not found
# Processing Record 57 | Velsk
# city not found
# Processing Record 58 | San Quintin
# city not found
# Processing Record 59 | Bilma
# Processing Record 60 | Lavrentiya
# Processing Record 61 | Tessalit
# city not found
# Processing Record 62 | Bucerias
# city not found
# Processing Record 63 | Canmore
# Processing Record 64 | Hithadhoo
# Processing Record 65 | Esna
# Processing Record 66 | Arraial do Cabo
# Processing Record 67 | At-Bashi
# Processing Record 68 | Havre-Saint-Pierre
# Processing Record 69 | Saint-Philippe
# Processing Record 70 | Nabire
# Processing Record 71 | Kahului
# Processing Record 72 | Severo-Kurilsk
# Processing Record 73 | Srednekolymsk
# Processing Record 74 | Vaini
# Processing Record 75 | Lufilufi
# Processing Record 76 | Butaritari
# Processing Record 77 | Chokurdakh
# city not found
# Processing Record 78 | Hermanus
# Processing Record 79 | Chapais
# Processing Record 80 | Bluff
# Processing Record 81 | Ahipara
# Processing Record 82 | Seoul
# Processing Record 83 | La Ronge
# Processing Record 84 | Prokudskoye
# Processing Record 85 | Aykhal
# Processing Record 86 | Paciran
# Processing Record 87 | Ha Tinh
# Processing Record 88 | Corrente
# Processing Record 89 | Ulaanbaatar
# Processing Record 90 | Cadiz
# city not found
# Processing Record 91 | Sao Lourenco do Sul
# Processing Record 92 | Broken Hill
# Processing Record 93 | Georgetown
# Processing Record 94 | Mount Gambier
# Processing Record 95 | Socorro
# Processing Record 96 | Hobart
# Processing Record 97 | Gat
# Processing Record 98 | Ilulissat
# Processing Record 99 | Lincolnton
# city not found
# Processing Record 100 | Ayan
# Processing Record 101 | Hilo
# Processing Record 102 | San Patricio
# Processing Record 103 | Saurimo
# Processing Record 104 | Mahebourg
# Processing Record 105 | Lokosovo
# Processing Record 106 | Grindavik
# Processing Record 107 | Tacuarembo
# Processing Record 108 | Zhezkazgan
# Processing Record 109 | Shimoda
# Processing Record 110 | Cidreira
# Processing Record 111 | San Rafael
# Processing Record 112 | Puerto Ayora
# Processing Record 113 | Pesochnoye
# Processing Record 114 | Mbanza-Ngungu
# city not found
# Processing Record 115 | Bathsheba
# Processing Record 116 | Rawson
# Processing Record 117 | Mukhen
# Processing Record 118 | Tuktoyaktuk
# Processing Record 119 | Vanavara
# Processing Record 120 | Talnakh
# Processing Record 121 | Narsaq
# Processing Record 122 | Saint George
# Processing Record 123 | Provideniya
# Processing Record 124 | Burnie
# city not found
# Processing Record 125 | Cape Town
# Processing Record 126 | Xiaoweizhai
# Processing Record 127 | Evensk
# Processing Record 128 | Los Llanos de Aridane
# Processing Record 129 | Komsomolskiy
# Processing Record 130 | Nyurba
# Processing Record 131 | Itarema
# Processing Record 132 | Kununurra
# city not found
# Processing Record 133 | Saint-Francois
# Processing Record 134 | Nikolskoye
# Processing Record 135 | Chara
# Processing Record 136 | Richards Bay
# city not found
# Processing Record 137 | Saint Anthony
# Processing Record 138 | Dikson
# Processing Record 139 | Geraldton
# Processing Record 140 | Beloha
# Processing Record 141 | Adrar
# Processing Record 142 | Matagami
# Processing Record 143 | Santa Vitoria do Palmar
# Processing Record 144 | Yerbogachen
# Processing Record 145 | Alice Springs
# Processing Record 146 | Kieta
# Processing Record 147 | Mahasamund
# Processing Record 148 | Alta Floresta
# city not found
# Processing Record 149 | Pisz
# Processing Record 150 | Humboldt
# Processing Record 151 | Ancud
# city not found
# Processing Record 152 | Yumen
# Processing Record 153 | Sitka
# Processing Record 154 | Chuy
# Processing Record 155 | Bossier City
# Processing Record 156 | Krasnoarmeysk
# Processing Record 157 | Dwarka
# Processing Record 158 | Pevek
# Processing Record 159 | Locri
# Processing Record 160 | Tahoua
# Processing Record 161 | Rujewa
# Processing Record 162 | Bonthe
# Processing Record 163 | Okhotsk
# Processing Record 164 | Pauini
# Processing Record 165 | Sandur
# Processing Record 166 | Atuona
# city not found
# Processing Record 167 | Faanui
# Processing Record 168 | Poum
# Processing Record 169 | Champerico
# Processing Record 170 | Billings
# Processing Record 171 | Fare
# Processing Record 172 | Half Moon Bay
# Processing Record 173 | Moron
# Processing Record 174 | Ugoofaaru
# Processing Record 175 | Esperance
# Processing Record 176 | Corpus Christi
# Processing Record 177 | Homer
# city not found
# Processing Record 178 | Carnarvon
# Processing Record 179 | Ipilan
# city not found
# city not found
# Processing Record 180 | Tasiilaq
# Processing Record 181 | Tura
# Processing Record 182 | Verkhnyaya Inta
# Processing Record 183 | Labuhan
# city not found
# Processing Record 184 | Codrington
# Processing Record 185 | Ola
# Processing Record 186 | Strezhevoy
# Processing Record 187 | Biak
# Processing Record 188 | Kenai
# Processing Record 189 | Minden
# Processing Record 190 | Kutum
# Processing Record 191 | Montrose
# city not found
# Processing Record 192 | Hun
# Processing Record 193 | Wolsztyn
# Processing Record 194 | Toora-Khem
# Processing Record 195 | Victoria
# Processing Record 196 | Garissa
# city not found
# Processing Record 197 | Norman Wells
# Processing Record 198 | Aklavik
# Processing Record 199 | Tianpeng
# city not found
# city not found
# Processing Record 200 | Vila Velha
# Processing Record 201 | Anahuac
# Processing Record 202 | Harmanli
# Processing Record 203 | Alanya
# Processing Record 204 | Ridgetown
# Processing Record 205 | Kalmunai
# city not found
# Processing Record 206 | Tilichiki
# city not found
# Processing Record 207 | Zalantun
# Processing Record 208 | Gunnedah
# Processing Record 209 | Tabou
# Processing Record 210 | Teknaf
# Processing Record 211 | Lakhipur
# Processing Record 212 | Castro
# Processing Record 213 | Peterhead
# Processing Record 214 | Lasa
# Processing Record 215 | Nanortalik
# Processing Record 216 | Hamilton
# Processing Record 217 | Port Hardy
# Processing Record 218 | Nikolayevka
# Processing Record 219 | Havoysund
# Processing Record 220 | Trelew
# Processing Record 221 | South River
# Processing Record 222 | Bethel
# Processing Record 223 | Kalang
# Processing Record 224 | Lorengau
# Processing Record 225 | Kizema
# Processing Record 226 | Sao Gabriel da Cachoeira
# Processing Record 227 | Torbay
# Processing Record 228 | Kurilsk
# Processing Record 229 | Gamba
# Processing Record 230 | Witu
# Processing Record 231 | Hobyo
# Processing Record 232 | Hualmay
# Processing Record 233 | Nelson Bay
# Processing Record 234 | Bath
# Processing Record 235 | Baghdad
# city not found
# Processing Record 236 | San Francisco
# Processing Record 237 | Portland
# Processing Record 238 | Mehamn
# Processing Record 239 | Tiksi
# Processing Record 240 | Bambous Virieux
# Processing Record 241 | Chor
# Processing Record 242 | Ketchikan
# Processing Record 243 | Harper
# Processing Record 244 | Vanimo
# Processing Record 245 | Ibra
# Processing Record 246 | Gombong
# city not found
# Processing Record 247 | Cangucu
# Processing Record 248 | Sorland
# Processing Record 249 | Kavaratti
# Processing Record 250 | Bonga
# Processing Record 251 | Sao Joao da Barra
# Processing Record 252 | Touros
# Processing Record 253 | Thinadhoo
# city not found
# Processing Record 254 | Guerrero
# Processing Record 255 | Diffa
# Processing Record 256 | Kirakira
# Processing Record 257 | Quesnel
# Processing Record 258 | Cranbrook
# Processing Record 259 | Vidim
# Processing Record 260 | Resistencia
# Processing Record 261 | Karratha
# Processing Record 262 | Naryan-Mar
# Processing Record 263 | Calvinia
# Processing Record 264 | Pisco
# Processing Record 265 | San Joaquin
# Processing Record 266 | Pangnirtung
# Processing Record 267 | Zorritos
# Processing Record 268 | Staraya Russa
# Processing Record 269 | Vyazemskiy
# Processing Record 270 | Phultala
# Processing Record 271 | Taoudenni
# Processing Record 272 | Pochutla
# city not found
# Processing Record 273 | Kurumkan
# Processing Record 274 | Batagay
# Processing Record 275 | Sycamore
# Processing Record 276 | Katobu
# Processing Record 277 | Severobaykalsk
# Processing Record 278 | Lamu
# Processing Record 279 | Vostok
# Processing Record 280 | Doksy
# city not found
# Processing Record 281 | Guthrie
# Processing Record 282 | Port Lincoln
# Processing Record 283 | Alofi
# Processing Record 284 | Henties Bay
# Processing Record 285 | Neiafu
# city not found
# Processing Record 286 | Paita
# Processing Record 287 | Lake Jackson
# Processing Record 288 | Wanning
# city not found
# Processing Record 289 | Mardin
# Processing Record 290 | Langarud
# city not found
# Processing Record 291 | Tabligbo
# Processing Record 292 | Pershotravneve
# Processing Record 293 | Tabuk
# Processing Record 294 | Vilyuysk
# Processing Record 295 | Rocha
# Processing Record 296 | Rawdon
# city not found
# Processing Record 297 | Port Augusta
# Processing Record 298 | Kaitangata
# Processing Record 299 | Jiwani
# Processing Record 300 | Gelemso
# Processing Record 301 | Iqaluit
# city not found
# Processing Record 302 | Port Hedland
# Processing Record 303 | Zhifang
# Processing Record 304 | Cabo San Lucas
# Processing Record 305 | Nalut
# city not found
# Processing Record 306 | Panguna
# Processing Record 307 | Nome
# Processing Record 308 | Flinders
# Processing Record 309 | Oktyabrskoye
# Processing Record 310 | Lebu
# city not found
# Processing Record 311 | Oistins
# Processing Record 312 | Mahajanga
# Processing Record 313 | Puerto Lempira
# Processing Record 314 | Tommot
# Processing Record 315 | Paamiut
# Processing Record 316 | Tamale
# Processing Record 317 | Sobolevo
# Processing Record 318 | Praxedis Guerrero
# Processing Record 319 | Kirovsk
# city not found
# Processing Record 320 | Sur
# Processing Record 321 | Constitucion
# Processing Record 322 | Kayerkan
# Processing Record 323 | Sao Jose da Coroa Grande
# Processing Record 324 | Tiarei
# city not found
# Processing Record 325 | Dalby
# Processing Record 326 | Doha
# Processing Record 327 | Cayeli
# Processing Record 328 | Zilupe
# Processing Record 329 | Orlik
# Processing Record 330 | Zaozerne
# city not found
# Processing Record 331 | Aljezur
# Processing Record 332 | Parangan
# Processing Record 333 | Souillac
# Processing Record 334 | Solnechnyy
# Processing Record 335 | Hyvinkaa
# Processing Record 336 | Te Anau
# city not found
# Processing Record 337 | Taganak
# Processing Record 338 | Grand-Lahou
# Processing Record 339 | Morondava
# Processing Record 340 | Aksarka
# Processing Record 341 | Longyearbyen
# Processing Record 342 | Kaitong
# Processing Record 343 | Piet Retief
# Processing Record 344 | Dali
# Processing Record 345 | Kruisfontein
# Processing Record 346 | Elko
# Processing Record 347 | Le Port
# Processing Record 348 | Vila Franca do Campo
# Processing Record 349 | Chingola
# city not found
# Processing Record 350 | Saldanha
# Processing Record 351 | Klaksvik
# Processing Record 352 | Trat
# Processing Record 353 | Vysokogornyy
# Processing Record 354 | Romani
# Processing Record 355 | Sechura
# city not found
# Processing Record 356 | Tezu
# Processing Record 357 | Skovorodino
# Processing Record 358 | Ustka
# Processing Record 359 | Bitung
# Processing Record 360 | San Ramon
# Processing Record 361 | Sao Felix do Xingu
# Processing Record 362 | Ahuimanu
# Processing Record 363 | East London
# Processing Record 364 | Leshukonskoye
# Processing Record 365 | Poronaysk
# Processing Record 366 | Wilmington
# Processing Record 367 | Marrakesh
# Processing Record 368 | Marawi
# Processing Record 369 | Sinnamary
# Processing Record 370 | Limaong
# Processing Record 371 | Uralets
# Processing Record 372 | Konotop
# Processing Record 373 | Semey
# Processing Record 374 | Nandu
# Processing Record 375 | Trincomalee
# Processing Record 376 | Alihe
# Processing Record 377 | Tchollire
# Processing Record 378 | Yinchuan
# Processing Record 379 | Mana
# city not found
# Processing Record 380 | Shirokiy
# Processing Record 381 | Plattsburgh
# Processing Record 382 | Olinda
# Processing Record 383 | Husavik
# Processing Record 384 | Bertoua
# Processing Record 385 | Great Bend
# Processing Record 386 | Lixourion
# Processing Record 387 | Lompoc
# Processing Record 388 | Male
# Processing Record 389 | Prieska
# city not found
# Processing Record 390 | Emilio Carranza
# Processing Record 391 | Isangel
# Processing Record 392 | Cayenne
# city not found
# Processing Record 393 | Arkhangelsk
# Processing Record 394 | Beatrice
# Processing Record 395 | Fomboni
# Processing Record 396 | Iracoubo
# Processing Record 397 | Kysyl-Syr
# Processing Record 398 | Necochea
# Processing Record 399 | Svetlogorsk
# Processing Record 400 | Bischofsheim
# Processing Record 401 | Simi Valley
# Processing Record 402 | Port Elizabeth
# Processing Record 403 | Visnes
# Processing Record 404 | San Matias
# city not found
# Processing Record 405 | Monster
# Processing Record 406 | Buala
# Processing Record 407 | Makokou
# Processing Record 408 | Impfondo
# Processing Record 409 | Turan
# Processing Record 410 | Huarmey
# Processing Record 411 | Sri Aman
# Processing Record 412 | Phonhong
# Processing Record 413 | Hokitika
# Processing Record 414 | Bilibino
# Processing Record 415 | Ballina
# Processing Record 416 | Sao Jose de Piranhas
# Processing Record 417 | Imphal
# Processing Record 418 | Brookhaven
# Processing Record 419 | Mildura
# Processing Record 420 | Mareeba
# Processing Record 421 | Marsa Matruh
# Processing Record 422 | Presidencia Roque Saenz Pena
# city not found
# Processing Record 423 | Tirau
# Processing Record 424 | Warrenton
# Processing Record 425 | Chinchani
# Processing Record 426 | Darnah
# Processing Record 427 | Corner Brook
# Processing Record 428 | Suntar
# Processing Record 429 | Amahai
# Processing Record 430 | Sierre
# Processing Record 431 | Priargunsk
# Processing Record 432 | Petropavl
# Processing Record 433 | Luderitz
# Processing Record 434 | Barabai
# Processing Record 435 | Warmbad
# Processing Record 436 | Fairbanks
# Processing Record 437 | Farmington
# Processing Record 438 | Aranos
# Processing Record 439 | Omboue
# Processing Record 440 | Biltine
# Processing Record 441 | Dallas
# Processing Record 442 | Rio Gallegos
# Processing Record 443 | Barahona
# Processing Record 444 | Mancora
# Processing Record 445 | Marcala
# Processing Record 446 | Joshimath
# Processing Record 447 | Bosaso
# Processing Record 448 | Yarada
# Processing Record 449 | Pyapon
# Processing Record 450 | Saharanpur
# Processing Record 451 | High Level
# Processing Record 452 | Bontang
# Processing Record 453 | Bandarbeyla
# Processing Record 454 | Wattegama
# Processing Record 455 | Cabedelo
# Processing Record 456 | Xining
# Processing Record 457 | Maromitsa
# Processing Record 458 | Bad Waldsee
# Processing Record 459 | Vestmannaeyjar
# Processing Record 460 | Iskateley
# city not found
# Processing Record 461 | Tshane
# Processing Record 462 | Ternate
# Processing Record 463 | Mumford
# Processing Record 464 | Jian
# city not found
# Processing Record 465 | Teresa
# Processing Record 466 | Luhyny
# Processing Record 467 | Demba
# Processing Record 468 | Satuba
# Processing Record 469 | Maniitsoq
# Processing Record 470 | Daru
# Processing Record 471 | Mendoza
# Processing Record 472 | Marystown
# Processing Record 473 | Altamira
# Processing Record 474 | Caravelas
# city not found
# Processing Record 475 | Mnogovershinnyy
# Processing Record 476 | Rongcheng
# city not found
# Processing Record 477 | Juneau
# Processing Record 478 | Bend
# Processing Record 479 | Fredericksburg
# Processing Record 480 | Lithgow
# Processing Record 481 | Lloydminster
# Processing Record 482 | Genhe
# Processing Record 483 | Kuvandyk
# Processing Record 484 | Namibe
# Processing Record 485 | Vila
# Processing Record 486 | Hambantota
# Processing Record 487 | Mitsamiouli
# Processing Record 488 | Albanel
# city not found
# Processing Record 489 | Coahuayana
# Processing Record 490 | Fort-Shevchenko
# Processing Record 491 | Byron Bay
# Processing Record 492 | Tutoia
# Processing Record 493 | Tshikapa
# Processing Record 494 | Acari
# Processing Record 495 | Vardo
# Processing Record 496 | Novikovo
# Processing Record 497 | Stromness
# Processing Record 498 | Baykit
# Processing Record 499 | Lincoln
# Processing Record 500 | Kharp
# Processing Record 501 | Aswan
# Processing Record 502 | Shubarkuduk
# Processing Record 503 | Challapata
# city not found
# Processing Record 504 | Mayor Pablo Lagerenza
# Processing Record 505 | Goderich
# Processing Record 506 | Luanda
# city not found
# Processing Record 507 | Dingle
# Processing Record 508 | Flin Flon
# city not found
# Processing Record 509 | Tecoanapa
# Processing Record 510 | Bakchar
# Processing Record 511 | Morros
# Processing Record 512 | Melo
# Processing Record 513 | Kavarna
# Processing Record 514 | Pangody
# Processing Record 515 | Batavia
# Processing Record 516 | Atbasar
# Processing Record 517 | Morgaushi
# Processing Record 518 | Poya
# Processing Record 519 | Boa Vista
# Processing Record 520 | Mount Isa
# Processing Record 521 | Erenhot
# Processing Record 522 | Saint-Pierre
# Processing Record 523 | Kloulklubed
# Processing Record 524 | Kyshtovka
# Processing Record 525 | Farah
# Processing Record 526 | Angoche
# Processing Record 527 | Avera
# Processing Record 528 | Jiutai
# Processing Record 529 | Terra Santa
# Processing Record 530 | Muswellbrook
# Processing Record 531 | Lagoa
# Processing Record 532 | Peniche
# Processing Record 533 | Canyon
# Processing Record 534 | Marica
# Processing Record 535 | Samarai
# Processing Record 536 | Sao Luis de Montes Belos
# Processing Record 537 | Jinzhou
# Processing Record 538 | Ahmadnagar
# Processing Record 539 | Tikhvin
# Processing Record 540 | Emborion
# Processing Record 541 | Ibirama

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity":humidity,
    "Lat": lats,
    "Lng": lngs,
    "Max temp": max_temps,
    "Wind Speed":wind_speeds
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          541
# Cloudiness    541
# Country       541
# Date          541
# Humidity      541
# Lat           541
# Lng           541
# Max temp      541
# Wind Speed    541
# dtype: int64

# %%
weather_data.to_csv("../WeatherPy-homework/weather_data.csv")
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Busselton          31      AU  1567541789        56 -33.64  115.35
# 1       Khatanga          94      RU  1567541789        85  71.98  102.47
# 2  Cockburn Town           0      TC  1567541789        74  21.46  -71.14
# 3       La Sarre         100      CA  1567541492        61  48.80  -79.20
# 4        Rikitea         100      PF  1567541525        87 -23.12 -134.97
#
#    Max temp  Wind Speed
# 0     50.00       29.95
# 1     43.83        9.69
# 2     84.15       13.27
# 3     55.35       12.35
# 4     72.09        9.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max temp"], marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (9/3/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (9/3/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (9/3/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (9/3/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()
